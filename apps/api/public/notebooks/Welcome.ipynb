# %% [markdown]
# # Welcome to the Enhanced Notebook Viewer! 📓
#
# This notebook demonstrates the **improved output visibility** with:
#
# - ✅ **High contrast outputs** with clear borders
# - ✅ **Color-coded cells** (Green inputs, Blue outputs)
# - ✅ **Terminal-style** stream outputs
# - ✅ **Larger text** for better readability
#
# ## Test Different Output Types

# %%
print("🎉 Hello from the notebook viewer!")
print("Notice the terminal-style green text on dark background")
# Out:
# 🎉 Hello from the notebook viewer!
# Notice the terminal-style green text on dark background

# %%
import numpy as np

# Create array - notice the clear output box
arr = np.arange(6).reshape(2, 3)
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# ## Statistics Output
#
# Notice how the output is clearly visible with white background and borders:

# %%
print("📊 Array Statistics:")
print(f"Mean: {arr.mean()}")
print(f"Std Dev: {arr.std()}")
print(f"Min: {arr.min()}")
print(f"Max: {arr.max()}")
# Out:
# 📊 Array Statistics:
# Mean: 2.5
# Std Dev: 1.707825127659933
# Min: 0
# Max: 5

# %% [markdown]
# ## Visual Improvements
#
# ### ✨ What's Different?
#
# 1. **Input Cells** (above) have green/emerald accent
# 2. **Output Cells** (below) have blue accent with white background
# 3. **Stream outputs** look like a real terminal
# 4. **Text is larger** (14px instead of 12px)
# 5. **Borders are thicker** and more visible
#
# ### 🎨 Color Coding
#
# - 🟢 **Green** = Code input ("In [n]")
# - 🔵 **Blue** = Results output ("Out[n]")
# - 🖥️ **Dark terminal** = Print statements
# - 🔴 **Red** = Errors (try below!)
